# %% [markdown]
# ## Imports

# %%
# %pip install -q langchain langchain-nvidia-ai-endpoints gradio
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\req_command.py", line 68, in wrapper
#     return func(self, options, args)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\commands\install.py", line 459, in run
#     installed = install_given_reqs(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\req\__init__.py", line 83, in install_given_reqs
#     requirement.install(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\req\req_install.py", line 867, in install
#     install_wheel(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 728, in install_wheel
#     _install_wheel(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 645, in _install_wheel
#     generated_console_scripts = maker.make_multiple(scripts_to_generate)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 446, in make_multiple
#     filenames.extend(self.make(specification, options))
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 417, in make
#     return super().make(specification, options)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 435, in make
#     self._make_script(entry, filenames, options=options)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 340, in _make_script
#     self._write_script(scriptnames, shebang, script, filenames, ext)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 265, in _write_script
#     launcher = self._get_launcher('t')
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 414, in _get_launcher
#     raise ValueError(msg)
# ValueError: Unable to find resource t64.exe in package pip._vendor.distlib

# %%
! pip install rich
# Out:
# Collecting rich
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from rich) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from rich) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Installing collected packages: rich
# Successfully installed rich-14.2.0

# %%
from functools import partial
from rich.console import Console
from rich.style import Style
from rich.theme import Theme

console = Console()
base_style = Style(color="#00ADB9", bold=True)
pprint = partial(console.print, style=base_style)

# %%
# !pip install -U langchain-nvidia-ai-endpoints
# Out:
# Collecting langchain-nvidia-ai-endpoints
#   Using cached langchain_nvidia_ai_endpoints-1.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp<4.0.0,>=3.9.1 (from langchain-nvidia-ai-endpoints)
#   Using cached aiohttp-3.13.2-cp310-cp310-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-nvidia-ai-endpoints) (1.2.0)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain-nvidia-ai-endpoints)
#   Using cached langchain_core-1.2.5-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->langchain-nvidia-ai-endpoints) (1.22.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints)
#   Using cached langsmith-0.5.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (4.12.0)
# Requirement already satisfied: certifi in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (1.0.9)
# Requirement already satisfied: idna in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (2.6.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-nvidia-ai-endpoints) (1.3.1)
# Using cached langchain_nvidia_ai_endpoints-1.0.0-py3-none-any.whl (46 kB)
# Using cached aiohttp-3.13.2-cp310-cp310-win_amd64.whl (455 kB)
# Using cached langchain_core-1.2.5-py3-none-any.whl (484 kB)
# Using cached langsmith-0.5.2-py3-none-any.whl (283 kB)
# Installing collected packages: aiohttp, langsmith, langchain-core, langchain-nvidia-ai-endpoints
#
#    ---------------------------------------- 0/4 [aiohttp]
#    ---------------------------------------- 0/4 [aiohttp]
#    ---------- ----------------------------- 1/4 [langsmith]
#    ---------- ----------------------------- 1/4 [langsmith]
#    ---------- ----------------------------- 1/4 [langsmith]
#    ---------- ----------------------------- 1/4 [langsmith]
#    -------------------- ------------------- 2/4 [langchain-core]
#    -------------------- ------------------- 2/4 [langchain-core]
#    -------------------- ------------------- 2/4 [langchain-core]
#    -------------------- ------------------- 2/4 [langchain-core]
#    -------------------- ------------------- 2/4 [langchain-core]
#    -------------------- ------------------- 2/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-nvidia-ai-endpoints]
#    ---------------------------------------- 4/4 [langchain-nvidia-ai-endpoints]
#
# Successfully installed aiohttp-3.13.2 langchain-core-1.2.5 langchain-nvidia-ai-endpoints-1.0.0 langsmith-0.5.2

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA
import os

api_key = os.getenv("NVIDIA_API_KEY")
os.environ["NVIDIA_API_KEY"] = api_key
print(api_key)
# ChatNVIDIA.get_available_models()
# Out:
# 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

# %%
# Useful utility method for printing intermediate states
from langchain_core.runnables import RunnableLambda
from functools import partial


def RPrint(preface="State: "):
    def print_and_return(x, preface=""):
        print(f"{preface}{x}")
        return x
    return RunnableLambda(partial(print_and_return, preface=preface))


def PPrint(preface="State: "):
    def print_and_return(x, preface=""):
        pprint(preface, x)
        return x
    return RunnableLambda(partial(print_and_return, preface=preface))

# %% [markdown]
# # Cricket Chatbot

# %% [markdown]
# ### Wikipedia Data Generation

# %%
# %pip install --upgrade --quiet  wikipedia
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'wikipedia' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'wikipedia'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
# !pip install -U langchain-community wikipedia
# Out:
# Collecting langchain-community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: wikipedia in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-community) (1.2.5)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Using cached langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Using cached sqlalchemy-2.0.45-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Using cached pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-community) (0.5.2)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=1.26.2 (from langchain-community)
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Using cached langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.0)
# Requirement already satisfied: certifi in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.2)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community)
#   Using cached greenlet-3.3.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from wikipedia) (4.14.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from beautifulsoup4->wikipedia) (2.8.1)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Using cached sqlalchemy-2.0.45-cp310-cp310-win_amd64.whl (2.1 MB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached greenlet-3.3.0-cp310-cp310-win_amd64.whl (300 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv, numpy, mypy-extensions, marshmallow, httpx-sse, greenlet, async-timeout, typing-inspect, SQLAlchemy, pydantic-settings, dataclasses-json, langchain-text-splitters, langchain-classic, langchain-community
#
#    ----------------------------------------  0/14 [python-dotenv]
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\req_command.py", line 68, in wrapper
#     return func(self, options, args)
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\commands\install.py", line 459, in run
#     installed = install_given_reqs(
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\req\__init__.py", line 83, in install_given_reqs
#     requirement.install(
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\req\req_install.py", line 867, in install
#     install_wheel(
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 728, in install_wheel
#     _install_wheel(
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 645, in _install_wheel
#     generated_console_scripts = maker.make_multiple(scripts_to_generate)
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 446, in make_multiple
#     filenames.extend(self.make(specification, options))
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 417, in make
#     return super().make(specification, options)
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 435, in make
#     self._make_script(entry, filenames, options=options)
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 340, in _make_script
#     self._write_script(scriptnames, shebang, script, filenames, ext)
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 265, in _write_script
#     launcher = self._get_launcher('t')
#   File "C:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 414, in _get_launcher
#     raise ValueError(msg)
# ValueError: Unable to find resource t64.exe in package pip._vendor.distlib

# %%
from langchain_community.document_loaders import WikipediaLoader
from datetime import datetime, timedelta
import os
import json

# Load documents from Wikipedia
docs = WikipediaLoader(query="Cricket and everything related to cricket",
                       load_max_docs=1000).load()

# Function to split text into chunks with headers


def create_chunks_with_headers(doc, doc_index):
    chunk_size = 1536
    chunk_overlap = 200
    chunks = []
    start = 0
    doc_content = doc.page_content
    doc_length = len(doc.page_content)

    while start < doc_length:
        end = min(start + chunk_size, doc_length)
        chunk = doc_content[start:end]

        if start != 0:
            chunk = doc_content[max(start - chunk_overlap, 0):end]

        chunk_json = {
            "meta_data": {
                "title": doc.metadata["title"],
                "summary": doc.metadata['summary'],
                "source_url": doc.metadata['source'],
            },
            "chunk_index": len(chunks) + 1,
            "content": chunk
        }
        chunks.append(chunk_json)

        start += chunk_size

    return chunks


# Create an array to store all document chunks as JSON objects
all_chunks = []

# Create JSON objects for each document with chunks
for i, doc in enumerate(docs):
    chunks = create_chunks_with_headers(doc, i + 1)
    all_chunks.extend(chunks)
    print(f"Data for document {i + 1} has been processed.")

# Output the array of JSON objects (for demonstration purposes)


# If you want to write the array to a file:
# with open('wikipedia_docs_chunks.json', 'w', encoding='utf-8') as file:
#     json.dump(all_chunks, file, ensure_ascii=False, indent=4)

print("All data has been processed.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from langchain_community.document_loaders import WikipediaLoader
#       2 from datetime import datetime, timedelta
#       3 import os
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
len(all_chunks)
# Out:
# 1377

# %% [markdown]
# Text splitting done into chunks with meta data for context

# %% [markdown]
# # Self Query Retriever

# %%
# %pip install --upgrade --quiet  lark langchain-chroma
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\req_command.py", line 68, in wrapper
#     return func(self, options, args)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\commands\install.py", line 459, in run
#     installed = install_given_reqs(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\req\__init__.py", line 83, in install_given_reqs
#     requirement.install(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\req\req_install.py", line 867, in install
#     install_wheel(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 728, in install_wheel
#     _install_wheel(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 645, in _install_wheel
#     generated_console_scripts = maker.make_multiple(scripts_to_generate)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 446, in make_multiple
#     filenames.extend(self.make(specification, options))
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 417, in make
#     return super().make(specification, options)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 435, in make
#     self._make_script(entry, filenames, options=options)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 340, in _make_script
#     self._write_script(scriptnames, shebang, script, filenames, ext)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 265, in _write_script
#     launcher = self._get_launcher('t')
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 414, in _get_launcher
#     raise ValueError(msg)
# ValueError: Unable to find resource t64.exe in package pip._vendor.distlib

# %%
pip install langchain-cohere
# Out:
# Collecting langchain-cohereNote: you may need to restart the kernel to use updated packages.
#
#   Using cached langchain_cohere-0.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting cohere<6.0,>=5.18.0 (from langchain-cohere)
#   Downloading cohere-5.20.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting langchain-community<0.5.0,>=0.4.0 (from langchain-cohere)
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0,>=1.0.0 (from langchain-cohere)
#   Using cached langchain_core-1.2.5-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-cohere) (2.12.5)
# Collecting types-pyyaml<7.0.0.0,>=6.0.12.20240917 (from langchain-cohere)
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere<6.0,>=5.18.0->langchain-cohere)
#   Downloading fastavro-1.12.1-cp310-cp310-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: httpx>=0.21.2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (0.28.1)
# Requirement already satisfied: pydantic-core>=2.18.2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.41.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (2.32.5)
# Collecting tokenizers<1,>=0.15 (from cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere<6.0,>=5.18.0->langchain-cohere)
#   Downloading types_requests-2.32.4.20250913-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from cohere<6.0,>=5.18.0->langchain-cohere) (4.15.0)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Downloading sqlalchemy-2.0.45-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached aiohttp-3.13.2-cp310-cp310-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain-cohere) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached langsmith-0.5.2-py3-none-any.whl.metadata (15 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=1.26.2 (from langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain-cohere) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0,>=1.0.0->langchain-cohere) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain-cohere) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (4.12.0)
# Requirement already satisfied: certifi in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (1.0.9)
# Requirement already satisfied: idna in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from pydantic<3,>=2->langchain-cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from pydantic<3,>=2->langchain-cohere) (0.4.2)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain-cohere) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain-cohere) (2.6.2)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Downloading greenlet-3.3.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached huggingface_hub-1.2.3-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached filelock-3.20.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting shellingham (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting typer-slim (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached typer_slim-0.21.0-py3-none-any.whl.metadata (16 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain-cohere)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: colorama in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ok\anaconda3\envs\chicken\lib\site-packages (from anyio->httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain-cohere) (1.3.1)
# Collecting click>=8.0.0 (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain-cohere)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Downloading langchain_cohere-0.5.0-py3-none-any.whl (42 kB)
# Downloading cohere-5.20.1-py3-none-any.whl (318 kB)
# Downloading fastavro-1.12.1-cp310-cp310-win_amd64.whl (449 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached aiohttp-3.13.2-cp310-cp310-win_amd64.whl (455 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached langchain_core-1.2.5-py3-none-any.whl (484 kB)
# Using cached langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Using cached langsmith-0.5.2-py3-none-any.whl (283 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Downloading sqlalchemy-2.0.45-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 3.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 2.9 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.1 MB/s eta 0:00:00
# Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached huggingface_hub-1.2.3-py3-none-any.whl (520 kB)
# Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Downloading types_requests-2.32.4.20250913-py3-none-any.whl (20 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Downloading greenlet-3.3.0-cp310-cp310-win_amd64.whl (300 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.20.1-py3-none-any.whl (16 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typer_slim-0.21.0-py3-none-any.whl (47 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Installing collected packages: types-requests, types-pyyaml, tqdm, shellingham, python-dotenv, numpy, mypy-extensions, marshmallow, httpx-sse, hf-xet, greenlet, fsspec, filelock, fastavro, click, async-timeout, typing-inspect, typer-slim, SQLAlchemy, pydantic-settings, dataclasses-json, aiohttp, langsmith, huggingface-hub, tokenizers, langchain-core, langchain-text-splitters, cohere, langchain-classic, langchain-community, langchain-cohere
#
#    -- -------------------------------------  2/31 [tqdm]
#    -- -------------------------------------  2/31 [tqdm]
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\cli\req_command.py", line 68, in wrapper
#     return func(self, options, args)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\commands\install.py", line 459, in run
#     installed = install_given_reqs(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\req\__init__.py", line 83, in install_given_reqs
#     requirement.install(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\req\req_install.py", line 867, in install
#     install_wheel(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 728, in install_wheel
#     _install_wheel(
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 645, in _install_wheel
#     generated_console_scripts = maker.make_multiple(scripts_to_generate)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 446, in make_multiple
#     filenames.extend(self.make(specification, options))
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_internal\operations\install\wheel.py", line 417, in make
#     return super().make(specification, options)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 435, in make
#     self._make_script(entry, filenames, options=options)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 340, in _make_script
#     self._write_script(scriptnames, shebang, script, filenames, ext)
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 265, in _write_script
#     launcher = self._get_launcher('t')
#   File "c:\Users\ok\anaconda3\envs\chicken\lib\site-packages\pip\_vendor\distlib\scripts.py", line 414, in _get_launcher
#     raise ValueError(msg)
# ValueError: Unable to find resource t64.exe in package pip._vendor.distlib

# %%
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_cohere import CohereEmbeddings


embeddings_model = CohereEmbeddings(
    cohere_api_key="")

documents=[]

for chunk in all_chunks:
    doc = Document(
            page_content=chunk["content"],
        metadata=chunk["meta_data"],
        )
    documents.append(doc)

print(documents[0].metadata)

vectorstore = Chroma.from_documents(documents, embeddings_model)
# Out:
# {'title': 'Board of Control for Cricket in India', 'summary': "Board of Control for Cricket in India (BCCI) is the national governing body of cricket in India. Its headquarters is situated at the cricket centre in Churchgate, Mumbai. The BCCI is the wealthiest governing body of cricket in the world.\nThe BCCI was established in 1 December 1928 at Madras (currently Chennai) under Act XXI of 1860 of Madras and was subsequently reregistered under the Tamil Nadu Societies Registration Act, 1975. It is a consortium of state cricket associations that select their own representatives who elect the BCCI president. It joined the Imperial Cricket Conference in 1926 which later became the International Cricket Council. The BCCI is an autonomous, private organization that does not fall under the purview of the National Sports Federation of India of Government of India and does not receive any grants from the Ministry of Youth Affairs and Sports. The BCCI is influential in international cricket. The International Cricket Council shares the largest part of its revenue with the BCCI. IPL run by BCCI is one of the wealthiest sports leagues in the world. \nIn financial year 2023-2024, BCCI earned ₹16,875 crore (US$2.0 billion). BCCI paid ₹4,000 crore (US$480 million) in taxes for the financial year 2022-23.\nR. E. Grant Govan was the first BCCI president and Anthony De Mello was its first secretary. As of February 2023, Roger Binny is the incumbent BCCI president and Jay Shah is the secretary.\nBCCI has hosted multiple Cricket World Cups, and will host the 2026 T20 World Cup, the 2029 Champions Trophy, the 2031 Cricket World Cup, and the 2025 Women's Cricket World Cup.\nThe BCCI manages four squads that represent India in international cricket; the men's national cricket team, the women's national cricket team, the men's national under-19 cricket team and women's national under-19 cricket team. It also governs developmental India A, India B and India A women's teams. Its national selection committee, which is led by chief national selector, selects players for these teams. As part of its duties, the BCCI organises and schedules matches to be played by each of these teams, and schedules, sanctions and organises domestic cricket in India.", 'source_url': 'https://en.wikipedia.org/wiki/Board_of_Control_for_Cricket_in_India'}

# %% [markdown]
# ### Creating our self-querying retriever
# Now we can instantiate our retriever. To do this we'll need to provide some information upfront about the metadata fields that our documents support and a short description of the document contents.

# %%
from langchain.chains.query_constructor.base import AttributeInfo
from langchain.retrievers.self_query.base import SelfQueryRetriever

metadata_field_info = [
    AttributeInfo(
        name="title",
        description="The name of the article",
        type="string",
    ),
    AttributeInfo(
        name="summary",
        description="The short summary of the article contents",
        type="integer",
    ),
    AttributeInfo(
        name="source_url",
        description="The web uri link to the article webpage",
        type="string",
    ),
]
document_content_description = "Data about cricket"
llm = ChatNVIDIA(model="mistralai/mistral-7b-instruct-v0.2")
retriever = SelfQueryRetriever.from_llm(
    llm,
    vectorstore,
    document_content_description,
    metadata_field_info,
)

# %%
from collections import deque

# Initialize memory as a deque with a maximum length of 5
memory = deque(maxlen=5)


def update_memory(user_question, response):

    memory.append({
        "question": user_question,
        "response": response,
    })
    pprint(memory)

# %% [markdown]
# ### Creating a pipeline for the retriever

# %%
from langchain_core.runnables import RunnableLambda, RunnableAssign, RunnablePassthrough
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate


sys_msg = """
You are an intelligent assistant that answers all questions about cricket using contextual information from Wikipedia. Your responses should be conversational and informative, providing clear and concise explanations. When relevant, include the source URL of the articles to give users additional reading material.

Always aim to:
1. Answer the question directly and clearly.
2. Provide context and background information when useful but do not give irrelevant information and answer to the point.
3. Suggest related topics or additional points of interest.
4. Be polite and engaging in your responses.
5. Remove the unnecessary context from the context provided if irrelevant to the question

Now, let's get started!
"""

# Initialize the chat model
instruct_chat = ChatNVIDIA(model="meta/llama3-70b-instruct")
llm = instruct_chat | StrOutputParser()


def generate_embeddings(input_data):
    embeddings = retriever.invoke(input_data)
    if embeddings:
        return embeddings
    else:
        return "No data available"


def generate_embeddings_query(input_data):
    prompt = ChatPromptTemplate.from_template(
        f"""
User's Question: {{input}}
Previous conversation memory {{memory}}
Generate only a query sentence and nothing else from the user's question to fetch from the data from embeddings. If the user's question does not have enough context then create a query based on the Knowledge Base.
"""
    )
    embedding_chain = prompt | llm
    embeddings_query = embedding_chain.invoke(input_data)
    if embeddings_query:
        return embeddings_query
    else:
        return "Process failed"


generate_embeddings_runnable = RunnableLambda(generate_embeddings)
generate_embeddings_query_runnable = RunnableLambda(generate_embeddings_query)



def get_response(prompt):
    return llm.invoke(prompt)


# Create the Runnable chain with memory integration
Runnable = (
    {"input": RunnablePassthrough(), "memory": RunnablePassthrough()}
    | RunnableAssign({"embedding_query": generate_embeddings_query_runnable})
    | RunnableAssign({"context": generate_embeddings_runnable})
    | RunnableAssign({"prompt": lambda x: ChatPromptTemplate.from_template(
        f"""
{sys_msg}

User's Question: {{input}}

Context Information: {{context}}

Previous Conversation memory: {{memory}}

Your Response:
"""
    )})
    | RunnableAssign({"response": lambda x: get_response(x["prompt"])})
    | PPrint()
    | RunnableAssign({"memory": lambda x: update_memory(x["input"]["input"], x["response"])})
)

# Get user input and invoke the chain
user_input = "Tell me more about his batting records"
response = Runnable.invoke({"input": user_input, "memory": memory})

pprint(response["response"])
# Out:
# /Users/abhiramyanampally/Downloads/NvidiaFrontend/.venv/lib/python3.12/site-packages/langchain_nvidia_ai_endpoints/_common.py:537: UserWarning: An API key is required for the hosted NIM. This will become an error in the future.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 83
#      81 # Get user input and invoke the chain
#      82 user_input = "Tell me more about his batting records"
# ---> 83 response = Runnable.invoke({"input": user_input, "memory": memory})
#      85 pprint(response["response"])
#
# NameError: name 'memory' is not defined
